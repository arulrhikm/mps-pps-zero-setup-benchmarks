# %%
import json
import bluequbit
from qiskit import QuantumCircuit
from qiskit.circuit.library import quantum_volume

bq = bluequbit.init("lEiTmm6zeLxxZ6q3aKBMsxwhrdnDr7vF")
# Out:
# [BQ-PYTHON-SDK][WARNING] - Beta version 0.18.1b1 of BlueQubit Python SDK is being used.
# [BQ-PYTHON-SDK][INFO] - There is a newer version of BlueQubit Python SDK available on PyPI. We recommend upgrading. Run 'pip install --upgrade bluequbit' to upgrade from your version 0.18.1b1 to 0.18.3b1.

# %%
num_qubits= 24
depth = 10
qc = quantum_volume(num_qubits, depth, seed=42)
print(qc.decompose().count_ops())
print(qc.decompose().size())
qc.decompose().draw()
# Out:
# OrderedDict({'u': 960, 'cx': 360})
# 1320
# global phase: 0.43446
#       ┌──────────────────────────┐                                 »
#  0: ──┤ U(1.2178,2.4228,-1.9912) ├─────────────────────────────────»
#      ┌┴──────────────────────────┤                                 »
#  1: ─┤ U(2.8388,0.99461,0.94918) ├─────────────────────────────────»
#      └─┬────────────────────────┬┘ ┌───┐┌─────────────────────────┐»
#  2: ───┤ U(1.751,1.8395,1.6412) ├──┤ X ├┤ U(1.2053,0.2736,0.9052) ├»
#     ┌──┴────────────────────────┴─┐└─┬─┘└─────────────────────────┘»
#  3: ┤ U(0.54806,-1.3914,-0.79635) ├──┼───────────────■─────────────»
#     └─┬──────────────────────────┬┘  │               │             »
#  4: ──┤ U(0.63555,1.8308,2.7705) ├───■───────────────┼─────────────»
#       └┬────────────────────────┬┘                   │             »
#  5: ───┤ U(0.801,3.1402,2.7829) ├────────────────────┼─────────────»
#      ┌─┴────────────────────────┴┐                 ┌─┴─┐           »
# ...

# %%
settings = [(34, 750), (35, 1), (35, 2)]
for setting in settings:
    for i in range(3):
        num_qubits, depth = setting
        qc = quantum_volume(num_qubits, depth, seed=42)
        num_gates = qc.size()
        job = bq.run(qc, device="gpu")
        queue_time = job.queue_time_ms
        run_time = job.run_time_ms
        run_time_per_gate = run_time / num_gates if num_gates > 0 else 0
        print(f"Depth: {depth}, Number of Gates: {num_gates}, Runtime: {run_time}, Queuetime: {queue_time}, Run time per gate (ms): {run_time_per_gate:.3f}")
# Out:
# [BQ-PYTHON-SDK][INFO] - Submitted: Job ID: UR33Hxz5PYipBaYB, device: gpu, run status: PENDING, created on: 2026-01-16 11:12:22 UTC, estimated runtime: 759100 ms, estimated cost: $3.17, num qubits: 34
# [BQ-PYTHON-SDK][INFO] - Status changed: Job ID: UR33Hxz5PYipBaYB. From PENDING to RUNNING.
# Depth: 750, Number of Gates: 12750, Runtime: 426095, Queuetime: 140812, Run time per gate (ms): 33.419
# [BQ-PYTHON-SDK][INFO] - Submitted: Job ID: ETU1UQGwWl95qHQb, device: gpu, run status: RUNNING, created on: 2026-01-16 11:22:44 UTC, estimated runtime: 759100 ms, estimated cost: $3.17, num qubits: 34
# Depth: 750, Number of Gates: 12750, Runtime: 426028, Queuetime: 720, Run time per gate (ms): 33.414
# [BQ-PYTHON-SDK][INFO] - Submitted: Job ID: NVPYUVoVllbqgQXA, device: gpu, run status: RUNNING, created on: 2026-01-16 11:30:49 UTC, estimated runtime: 759100 ms, estimated cost: $3.17, num qubits: 34
# ...

# %%
import numpy as np

# Collect trial data: dict[(num_qubits, depth)] = list of run_time_per_gate values
# trial_data = {}
num_qubits = 35

for depth in range(20, 120, 20):
# trial_data[(num_qubits, depth)] = []
# for trial in range(num_trials):
    qc = quantum_volume(num_qubits, depth, seed=42)
    num_gates = qc.size()
    job = bq.run(qc, device="gpu")
    run_time_per_gate = job.run_time_ms / num_gates if num_gates > 0 else 0
    print(f"Depth: {depth}, Run time per gate (ms): {run_time_per_gate:.6f}")
# Out:
# [BQ-PYTHON-SDK][INFO] - Submitted: Job ID: jSTbjeBIoeb0T0hp, device: gpu, run status: RUNNING, created on: 2026-01-14 18:20:56 UTC, estimated runtime: 144000 ms, estimated cost: $0.20, num qubits: 35
# ---------------------------------------------------------------------------
# BQJobNotCompleteError                     Traceback (most recent call last)
# Cell In[26], line 12
#      10 qc = quantum_volume(num_qubits, depth, seed=42)
#      11 num_gates = qc.size()
# ---> 12 job = bq.run(qc, device="gpu")
#      13 run_time_per_gate = job.run_time_ms / num_gates if num_gates > 0 else 0
#      14 print(f"Depth: {depth}, Run time per gate (ms): {run_time_per_gate:.6f}")
#
# File c:\Users\arulr\miniconda3\envs\bq\Lib\site-packages\bluequbit\bluequbit_client.py:419, in BQClient.run(self, circuits, device, asynchronous, job_name, shots, pauli_sum, options, tags)
#     413 logger.info("Submitted: %s", submitted_job)
#     414 if (
#     415     not asynchronous
# ...

# %%
import bluequbit
from qiskit import QuantumCircuit

qc = QuantumCircuit(2, 2)
qc.h(0)
qc.cx(0, 1)
qc.measure(1, 1)

bq_client = bluequbit.init("lEiTmm6zeLxxZ6q3aKBMsxwhrdnDr7vF")
res = bq_client.run(qc, "mps.cpu")
print(res.get_counts()) # should be {'0': 0.5000000000000001, '1': 0.4999999999999999}
# Out:
# [BQ-PYTHON-SDK][WARNING] - Beta version 0.18.1b1 of BlueQubit Python SDK is being used.
# [BQ-PYTHON-SDK][INFO] - There is a newer version of BlueQubit Python SDK available on PyPI. We recommend upgrading. Run 'pip install --upgrade bluequbit' to upgrade from your version 0.18.1b1 to 0.18.3b1.
# [BQ-PYTHON-SDK][INFO] - Submitted: Job ID: 7ghf6uUK1yEiVDFN, device: mps.cpu, run status: PENDING, created on: 2026-02-24 22:59:19 UTC, estimated runtime: 5000 ms, estimated cost: $0.00, num qubits: 2, shots: 1024
# [BQ-PYTHON-SDK][INFO] - Status changed: Job ID: 7ghf6uUK1yEiVDFN. From PENDING to RUNNING.
# {'0': 0.5000000000000001, '1': 0.4999999999999999}
